# %% [markdown]
# ## DATASET1
#
# The dataset is relevant to the analysis of employee financial behavior, retirement savings patterns, and their interaction with the accessible and locked pots in the retirement system. Here's why:
#
# ### 1. Demographic Factors
# The dataset includes variables such as gender and age, which are key demographic factors that can influence financial behavior and savings patterns.
#
# ### 2. Investment Choices
# The columns such as "Investment_Avenues", "Mutual_Funds", "Equity_Market", "Debentures", "Government_Bonds", "Fixed_Deposits", "PPF", and "Gold" reflect different investment options employees choose, which directly ties into how they might allocate funds between the accessible and locked pots in a retirement system.
#
# ### 3. Financial Objectives
# The column "What are your savings objectives?" and associated reasons for choosing different types of investments (e.g., "Reason_Equity", "Reason_Mutual", "Reason_FD") provide insight into the motivation behind financial decisions, which could influence how employees interact with the two pots.
#
# ### 4. Monitoring and Duration
# The columns "Duration" and "Invest_Monitor" offer information about the duration of investments and how frequently individuals monitor their portfolios, which can reflect short-term vs. long-term savings strategies relevant to retirement planning.
#
# ### 5. Savings Objectives and Preferences
# Information about expected returns ("Expect"), preferred investment avenues ("Avenue"), and reasons for choosing certain financial products offers direct insights into how people might balance between more accessible funds and long-term, locked investments for retirement.
#
# Overall, this dataset can provide meaningful insights into how employees might interact with both the Accessible Pot (shorter-term savings) and the Locked Pot (long-term retirement savings) in the two-pot retirement system.
#
#
#
# ### LINK
#
# https://www.kaggle.com/datasets/adhoppin/financial-data?resource=download
#
#
#
#
# ## DATASET2
#
# it is relevent because the dataset you provided contains several elements that can indeed relate to employee financial behavior, retirement savings patterns, income levels, demographic factors, and potentially even economic indicators. Here’s how each column can contribute to meaningful insights into employee interactions with the accessible and locked pots in the retirement system:
#
# ## Columns
#
# ### Employee_ID
# - This identifier allows for tracking individual responses without revealing personal details, enabling analysis of trends among different employees.
#
# ### Age
# - Age can be an essential demographic factor influencing retirement savings patterns. Younger employees might prioritize flexibility, while older employees might focus more on security and long-term savings.
#
# ### Income
# - Income levels are critical to understanding financial behavior. Higher income may correlate with greater savings potential, while lower income may indicate more financial strain.
#
# ### Years_of_Service
# - This metric can provide insights into how long employees have been saving and their familiarity with the retirement system. Employees with more years of service might have different attitudes towards the pots than newer employees.
#
# ### Financial_Obligations
# - This can indicate how much of their income is going towards other expenses, affecting their ability to save for retirement. Higher obligations may lead to lower savings in both pots.
#
# ### Withdrawals_Past_Year
# - The number of withdrawals can give insights into the accessibility of the funds and how often employees feel the need to access their savings. It can also indicate reliance on the accessible pot.
#
# ### Feedback
# - Employee feedback provides qualitative insights into their experiences and attitudes toward the retirement system. It can highlight areas for improvement and common concerns regarding savings and withdrawals.
#
# ## Potential Insights
#
# - **Impact of Age on Savings Behavior:** Analyze if younger employees tend to withdraw more frequently from the accessible pot compared to older employees, who might focus more on the locked pot.
#
# - **Income and Savings Correlation:** Investigate how income levels influence the amount employees save in both pots and their tendency to withdraw funds.
#
# - **Financial Obligations:** Explore how higher financial obligations correlate with increased withdrawals and decreased contributions to the retirement pots.
#
# - **Years of Service and Financial Literacy:** Determine if longer tenured employees express greater confidence in the retirement system compared to newer employees.
#
# - **Qualitative Analysis of Feedback:** Aggregate feedback to identify common themes, such as the need for better education on retirement savings, which can inform future training or informational sessions.
#
# ## Conclusion
#
# Overall, this dataset has the potential to provide meaningful insights into employee interactions with retirement savings systems, particularly in understanding how different demographic and financial factors influence their behavior regarding accessible and locked pots. You could enhance the analysis by adding economic indicators like inflation rates or interest rates for a more comprehensive understanding of external factors impacting employee savings behavior.
#
#
# ##CSV
#
# Employee_ID,Age,Income,Years_of_Service,Financial_Obligations,Withdrawals_Past_Year,Feedback
# 1,25,30000,1,1000,1,I like the flexibility of the system.
# 2,32,45000,5,2000,0,It's difficult to save enough for retirement.
# 3,45,60000,10,3000,2,The system is too complex for me.
# 4,29,32000,3,1500,0,I find it helpful for managing emergencies.
# 5,38,55000,8,2500,1,More education on long-term savings would help.
# 6,50,70000,20,4000,1,The withdrawal limits are too strict.
# 7,23,28000,0,800,1,I'm concerned about my savings depleting.
# 8,41,48000,15,2200,0,I appreciate having access when needed.
# 9,36,52000,12,1800,0,The locked pot gives me peace of mind.
# 10,48,75000,25,3500,2,I think the system is beneficial overall.
